# %%
import pandas as pd

# %%
df = pd.read_csv("./2010.csv")
df = df.drop("Unnamed: 0",axis=1)

# %%
df["song"] = df['Video'].apply(lambda x: x.split('-'))

# %%
df
# Out:
#                                                  Video  \
# 0                    Justin Bieber - Baby ft. Ludacris
# 1    Shakira - Waka Waka (This Time for Africa) (Th...
# 2            Eminem - Love The Way You Lie ft. Rihanna
# 3                          Adele - Rolling in the Deep
# 4    Bruno Mars - Just The Way You Are [OFFICIAL VI...
# 5                     Katy Perry - Firework (Official)
# 6                                  Eminem - Not Afraid
# 7                  Don Omar - Danza Kuduro ft. Lucenzo
# 8      Justin Bieber - Never Say Never ft. Jaden Smith
# 9                Bruno Mars - Grenade [OFFICIAL VIDEO]
# 10                 Rihanna - What's My Name? ft. Drake
# 11                  Rihanna - Only Girl (In The World)
# 12                  a-ha - Take On Me (Official Video)
# 13            Whitney Houston - I Will Always Love You
# 14   Enrique Iglesias, Juan Luis Guerra - Cuando Me...
# 15                  The Police - Every Breath You Take
# ...
