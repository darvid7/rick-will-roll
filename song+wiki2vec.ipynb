# %%
import pandas as pd

# %%
wiki = pd.read_csv("wiki.csv")

# %%
song = pd.read_csv("billboard.csv")

# %%
song = song.drop("Unnamed: 0",axis=1)

# %%
len(wiki)
# Out:
# 577

# %%
len(song)
# Out:
# 592

# %%
concat = pd.concat([wiki, song], axis=1, join='inner', keys="song",ignore_index=True)

# %%
concat = concat.drop([3,5],axis=1)

# %%
concat
# Out:
#                             0  \
# 0                     tik tok
# 1                need you now
# 2             hey soul sister
# 3            california gurls
# 4                         omg
# 5                   airplanes
# 6        love the way you lie
# 7                 bad romance
# 8                    dynamite
# 9            break your heart
# 10              nothin on you
# 11                  i like it
# 12                    bedrock
# 13                   rude boy
# 14                  telephone
# 15              teenage dream
# 16       just the way you are
# 17             cooler than me
# 18                    imma be
# 19       empire state of mind
# 20   dj got us fallin in love
# 21                billionaire
# 22                 not afraid
# 23                     replay
# 24                 sexy bitch
# 25                  breakeven
# 26       your love is my drug
# 27            i gotta feeling
# 28                  fireflies
# 29                    say aah
# ...
